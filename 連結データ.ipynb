# %% [markdown]
# <a href="https://colab.research.google.com/github/tsenga2/ibes-japan/blob/main/%E9%80%A3%E7%B5%90%E3%83%87%E3%83%BC%E3%82%BF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
from numpy import nan
import os

# %%
f = drive.CreateFile({'id': '1V080Vv3uFIeYoLKd9cFI3ZKc5Lb5WYUY'})
DBJ_list = drive.ListFile().GetList()[0]['id']
file_list = drive.ListFile({'q': '"1V080Vv3uFIeYoLKd9cFI3ZKc5Lb5WYUY" in parents and trashed = false'.format(DBJ_list)}).GetList()
for f in file_list:
     print(f['title'], f['id'])
# Out:
# Tdfken.docx 1_kObASr2SasGlOgOkQUqa6cFTyJZj8n0
# Tdfken.txt 1_65RtAiaVER1Q93iQdqKfbmn_zP7lfpI
# SijoKbn.txt 1KTj2lGcKkIVGTS-uLUgrL5UK9-YMnH2i
# JojoSijo.txt 1zT7gui1NZlpHbgSTDL30gGo4WZA6meCd
# JDBGyos.txt 12596vq8lCYv8MVOMmtnZxvYHdeGel21F
# CompInfo.txt 1GWog3ZW9ow4jU9IqCvH6Rx4yLloVsZ1M
# KinyuKkn.txt 1Ftzv2v0CX3I4IRAVIPoyCkSV7LiLEMDa
# SelItem.txt 1qLsvxYU2mP7kNbFin4iYwEdhcJyWBclB
# ComDef.txt 1xhkzeNEwuRAanvXz2GWWPITmCmEe5v2h
# Exchange.ini 1KQQJ3oOqfh-kCH0_kTONtkWfjfa8lsWF
# UpdateLog.txt 1U_QPqui3hs1t6WAw0T1JIgE6rf8WkpRq
# ExecuteList.txt 1PPENLsZz10FFfz5jclreThmAYOFA5YTs
# CompListedMarketHist.txt 1tV3_-xQwKWwNC9JcGrVKAi_SZua1LcQx
# HandGyos.txt 16x7FSxDE0YDoK_43YoUAzmQgMqRSOcxw
# 連結会社概況.txt 1s_OTNZfTZ5Ixy0Pn6f9k-SYIZf2Db5-k
# 連結注記事項.txt 1Exth9Zfqmne2urXcq4Q84iH8d4qg0_Jb
# 連結株主資本等変動計算書.txt 1a4KlIQ40kKQFwoIbfYup0ebm6bCHQt_C
# 連結事業状況.txt 1WjfBH-8TkYFcAmiiAYMk2Y-tU7m-9B37
# 連結貸借対照表2.txt 1QbnhFTaXM_hLx3Yuj1wivIK9EVVYuNF5
# 連結貸借対照表1.txt 1L9ENVmbY4-zkyfqVRZC6tHcvkRP53NMF
# 連結セグメント情報.txt 1LOBPDN5wGjJzxE9oYa0tpACAgsp1wqi5
# 連結キャッシュフロー計算書.txt 1SMrN8yc6tTlGtAbv5V0P1Xixr0EmId7I
# CoLstYRC.txt 17bAio1Bby9M1uHjx-euEuqrYz3d3Na4j
# 連結損益計算書.txt 1-XBiEIkYP5kZpWrgCe2nLwryL3P0zmaC

# %%
for f in file_list:
  if f['title'].isalpha() == False:
     fileDownloaded = drive.CreateFile({'id': f['id']})
     fileDownloaded.GetContentFile(f['title'])
  else: pass

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.rename('連結キャッシュフロー計算書.txt','conso_cashflow')
os.rename('連結セグメント情報.txt','conso_segment')
os.rename('連結会社概況.txt','conso_kaisha')
os.rename('連結株主資本等変動計算書.txt','conso_hendou')
os.rename('連結事業状況.txt','conso_overview')
os.rename('連結損益計算書.txt','conso_PL')
os.rename('連結貸借対照表1.txt','conso_BS1')
os.rename('連結貸借対照表2.txt','conso_BS2')
os.rename('連結注記事項.txt','conso_note')

# %%
dat1 =pd.read_table('conso_cashflow', sep=",", index_col=2)
dat2 =pd.read_table('conso_segment', sep=",", index_col=2)
dat3 =pd.read_table('conso_kaisha', sep=",", index_col=2)
dat4 =pd.read_table('conso_hendou', sep=",", index_col=2)
dat5 =pd.read_table('conso_overview', sep=",", index_col=2)
dat6 =pd.read_table('conso_PL', sep=",", index_col=2)
dat7 =pd.read_table('conso_BS1', sep=",", index_col=2)
dat8 =pd.read_table('conso_BS2', sep=",", index_col=2)
dat9 =pd.read_table('conso_note', sep=",", index_col=2)

dat10 = pd.concat([dat1,dat2,dat3,dat4,dat5,dat6,dat7,dat8,dat9],axis=1)


dat10 = dat10.T.drop_duplicates().T


dat10 = dat10.rename(columns={'会社ｺｰﾄﾞ':'Comp_code'})
dat10 = dat10.rename(columns={'株式銘柄ｺｰﾄﾞ':'Stock_code'})
dat10 = dat10.rename(columns={'決算期':'ap'})


col=dat10.columns.tolist()
p=col[:3]
q=col[3:]
q=[t[:10] for t in q]
col=p+q
dat10.columns=col
# Out:
# <ipython-input-92-8a71905f85cd>:2: DtypeWarning: Columns (244) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat2 =pd.read_table('conso_segment', sep=",", index_col=2)

# %%
dat10
# Out:
#                   Comp_code Stock_code       ap RCF0000100 RCF0000200  \
# 会社名
# 宇部興産（株）                   6       4208  1978-03        NaN        NaN
# 宇部興産（株）                   6       4208  1979-03        NaN        NaN
# 宇部興産（株）                   6       4208  1980-03        NaN        NaN
# 宇部興産（株）                   6       4208  1981-03        NaN        NaN
# 宇部興産（株）                   6       4208  1982-03        NaN        NaN
# ...                     ...        ...      ...        ...        ...
# （株）ＳＴＩフードホールディングス    119520       2932  2020-12        NaN  1281878.0
# ＳＡＮＥＩ（株）             119826       6230  2020-03        NaN  1081310.0
# ＳＡＮＥＩ（株）             119826       6230  2021-03        NaN  1622049.0
# （株）オーケーエム            119830       6229  2020-03        NaN   825223.0
# （株）オーケーエム            119830       6229  2021-03        NaN  1026196.0
#
#                   RCF0000300 RCF0000400 RCF0000500 RCF0000600 RCF0000700  ...  \
# 会社名                                                                       ...
# 宇部興産（株）                  NaN        NaN        NaN        NaN        NaN  ...
# 宇部興産（株）                  NaN        NaN        NaN        NaN        NaN  ...
# 宇部興産（株）                  NaN        NaN        NaN        NaN        NaN  ...
# 宇部興産（株）                  NaN        NaN        NaN        NaN        NaN  ...
# 宇部興産（株）                  NaN        NaN        NaN        NaN        NaN  ...
# ...                      ...        ...        ...        ...        ...  ...
# （株）ＳＴＩフードホールディングス   667377.0     3250.0        NaN    42385.0        NaN  ...
# ＳＡＮＥＩ（株）            446888.0        NaN        NaN        NaN    -2349.0  ...
# ＳＡＮＥＩ（株）            433355.0        NaN        NaN        NaN    -1084.0  ...
# （株）オーケーエム           301306.0        NaN        NaN        NaN     -745.0  ...
# （株）オーケーエム           339264.0        NaN        NaN        NaN       14.0  ...
#
#                   RCJ0017800 RCJ0017900 RCJ0018000 RCJ0018100 RCJ0018200  \
# 会社名
# 宇部興産（株）                  NaN        NaN        NaN        NaN   791000.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN   850000.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN   865000.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN  1053000.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN  1097000.0
# ...                      ...        ...        ...        ...        ...
# （株）ＳＴＩフードホールディングス        NaN        NaN        NaN        0.0   125672.0
# ＳＡＮＥＩ（株）                 NaN        NaN        NaN        0.0   854480.0
# ＳＡＮＥＩ（株）                 NaN        NaN        NaN        0.0   740342.0
# （株）オーケーエム                NaN        NaN        NaN        0.0   100807.0
# （株）オーケーエム                NaN        NaN        NaN        0.0    11091.0
#
#                   RCJ0018300 RCJ0018400 RCJ0018500 RCJ0018600 RCJ0018800
# 会社名
# 宇部興産（株）                  NaN        NaN        NaN        NaN      128.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN      167.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN      262.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN      238.0
# 宇部興産（株）                  NaN        NaN        NaN        NaN      169.0
# ...                      ...        ...        ...        ...        ...
# （株）ＳＴＩフードホールディングス    57707.0        NaN        NaN        NaN        NaN
# ＳＡＮＥＩ（株）                 0.0        NaN        NaN        NaN        NaN
# ＳＡＮＥＩ（株）                 0.0        NaN        NaN        NaN        NaN
# （株）オーケーエム            74286.0        NaN        NaN        NaN        NaN
# （株）オーケーエム            92632.0        NaN        NaN        NaN        NaN
#
# [76780 rows x 981 columns]

# %%
dat10.to_csv('renketsu.csv', index=True, encoding='utf-8')

# %%
from google.colab import files

# ファイルをダウンロード
files.download('renketsu.csv')
